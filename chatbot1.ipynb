# %%
#import library

import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#Data set

df = pd.read_csv("jokes.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of           ID                                           Question  \
# 0          1  Did you hear about the Native American man tha...
# 1          2       What's the best anti diarrheal prescription?
# 2          3  What do you call a person who is outside a doo...
# 3          4  Which Star Trek character is a member of the m...
# 4          5  What's the difference between a bullet and a h...
# ...      ...                                                ...
# 38264  38265  Q: Why did the pacifist /b/tard try to calm ev...
# 38265  38266            Q: Why can't Obama poke fun at himself?
# 38266  38267             Why is gambling not allowed in Africa?
# 38267  38268       What do you call three witches in a hot tub?
# 38268  38269  What do scientists use to measure a chicken's ...
#
#                                      Answer
# 0       He nearly drown in his own tea pee.
# 1                          Mycheexarphlexin
# 2                                      Matt
# 3                        Jean-Luc Pickacard
# 4             A bullet doesn't miss Harambe
# ...                                     ...
# 38264                    He did it for the
# 38265     A: Because that would be racist.
# 38266  Because there are too many cheetahs.
# 38267                A self-cleaning coven.
# 38268                          An egg timer
#
# [38269 rows x 3 columns]>

# %%
#Show Data at head

df.head(10)
# Out:
#    ID                                           Question  \
# 0   1  Did you hear about the Native American man tha...
# 1   2       What's the best anti diarrheal prescription?
# 2   3  What do you call a person who is outside a doo...
# 3   4  Which Star Trek character is a member of the m...
# 4   5  What's the difference between a bullet and a h...
# 5   6                 Why was the Ethiopian baby crying?
# 6   7  What's the difference between a corn husker wi...
# 7   8                     Who is 2016's biggest sellout?
# 8   9    Why is little Annie's shoe floating in the sea?
# 9  10  What's the difference between a married man an...
#
#                                               Answer
# 0                He nearly drown in his own tea pee.
# 1                                   Mycheexarphlexin
# 2                                               Matt
# 3                                 Jean-Luc Pickacard
# 4                      A bullet doesn't miss Harambe
# 5                    He was having a mid-life crisis
# 6                         One shucks between fits...
# 7                    Kevin Durant or Bernie Sanders?
# 8                         Because the shark burped.
# 9  A bachelor will go to the fridge, sees nothing...

# %% [markdown]
# # Cleaning the dataset:

# %%
#Drop ID colomn

df=df.drop(['ID'], axis=1)

# %%
#Show Data at Random

df.sample(10)
# Out:
#                                                 Question  \
# 9424                  How do you start making big bucks?
# 8028        What's big, black, and explodes when shaken?
# 31790                  What's the definition of "trust"?
# 8        Why is little Annie's shoe floating in the sea?
# 29371  What do you call someone who believes rotten e...
# 33896          What's the most useless thing on a woman?
# 20677  What do you call a woman that raps about woman...
# 16422                   What's your most fucked up joke?
# 16044                               When's sex not work?
# 3736               What do you call a fly with no wings?
#
#                                                   Answer
# 9424                                   With a little doe
# 8028                                      A COKe bottle.
# 31790                            Two cannibals doing 69.
# 8                             Because the shark burped.
# 29371                             An eggsy-stench-alist.
# 33896                                  A drunk Irishman.
# 20677                                            Feminem
# 16422  I'm looking for the most cancerous jokes you c...
# 16044                                When it's for play.
# 3736                                             A walk.

# %%
nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#removing special characters, numbers, and stopwords

def clean_text(text):
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = text.lower()
    text = text.split()
    text = [lemmatizer.lemmatize(word) for word in text if not word in stop_words]
    text = ' '.join(text)
    return text

# %%
df['cleaned_Question'] = df['Question'].apply(clean_text)
df['cleaned_Answer'] = df['Answer'].apply(clean_text)

# %%
df.sample(10)
# Out:
#                                                 Question  \
# 10438                 Do you know how electricity works?
# 35894  What did the lesbian vampire say to her girlfr...
# 2669                 Why can't the T-rex clap its hands?
# 35833                How do you know you're getting old?
# 10355  What do Caitlyn Jenner and my Chrysler have in...
# 21946      What do you call a person who is half Jewish?
# 6678        What do you tell a girl with two black eyes?
# 18669           Why is a roach clip called a roach clip?
# 8826   What do you call an alien that's also a pedoph...
# 16972  What do you call attempting to jump to light s...
#
#                                                 Answer  \
# 10438                         The truth may shock you.
# 35894                              See you next month!
# 2669                                Because it's dead.
# 35833   When you exit a museum, you trigger the alarm.
# 10355                       They're both convertables.
# 21946                                          Jew-ish
# 6678              Nothing, you already told her twice.
# 18669  Because pot holder was already taken -rim shot-
# 8826                               An Extramolestrial
# 16972                                A Wookie mistake!
#
#                                         cleaned_Question  \
# 10438                              know electricity work
# 35894                     lesbian vampire say girlfriend
# 2669                                       rex clap hand
# 35833                                   know getting old
# 10355                     caitlyn jenner chrysler common
# 21946                            call person half jewish
# 6678                             tell girl two black eye
# 18669                       roach clip called roach clip
# 8826                           call alien also pedophile
# 16972  call attempting jump light speed checking hype...
#
#                           cleaned_Answer
# 10438                    truth may shock
# 35894                     see next month
# 2669                                dead
# 35833          exit museum trigger alarm
# 10355                       convertables
# 21946                            jew ish
# 6678          nothing already told twice
# 18669  pot holder already taken rim shot
# 8826                     extramolestrial
# 16972                     wookie mistake

# %%
# Vectorize the text 
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['cleaned_Question'])
y = vectorizer.transform(df['cleaned_Answer'])

# %%
#Training the chatbot
def generate_response(user_input):
    user_input = clean_text(user_input)
    user_input_vector = vectorizer.transform([user_input])
    similarities = cosine_similarity(user_input_vector, X).flatten()
    index = np.argmax(similarities)
    return df['cleaned_Answer'][index]

# %%
# Testing the chatbot
while True:
    user_input = input('You: ')
    if user_input.lower() == 'quit':
        break
    response = generate_response(user_input)
    print('Chatbot:', response)
# Out:
# You: Do you know how electricity works?
# Chatbot: truth may shock
# You: call alien also pedophile
# Chatbot: extramolestrial
# You: Why is a roach clip called a roach clip?
# Chatbot: pot holder already taken rim shot
